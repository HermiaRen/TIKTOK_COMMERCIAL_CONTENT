# %% [markdown]
# Preparing data for machine learning.

# %%
import pandas as pd

# %%
ads_df = pd.read_csv("Resources/merged_data.csv")
ads_df.head(10)
# Out:
#               ad.id                                      ad.image_urls  \
# 0  1776307088392242  ['https://p21-ad-sg.ibyteimg.com/origin/tos-al...
# 1  1753834789213233  ['https://p21-ad-sg.ibyteimg.com/origin/tos-ma...
# 2  1763792178958354  ['https://p16-csp-adlib-site-sign-sg.ibyteimg....
# 3  1776997064735793  ['https://p21-ad-sg.ibyteimg.com/origin/tos-al...
# 4  1780531640408097  ['https://p19-csp-adlib-site-sign-sg.ibyteimg....
# 5  1777368392966177  ['https://p16-csp-adlib-site-sign-sg.ibyteimg....
# 6  1776757321591842                                                NaN
# 7  1767336884647969                                                NaN
# 8  1754736720243826  ['https://p19-csp-adlib-site-sign-sg.ibyteimg....
# 9  1780031997939730  ['https://p21-ad-sg.ibyteimg.com/origin/tos-al...
#
#    ad.last_shown_date ad.reach.unique_users_seen_x ad.status  \
# 0            20231117                      10M-20M    active
# 1            20230417                      10M-20M    active
# 2            20230428                      10M-20M    active
# 3            20231113                      10M-20M    active
# 4            20231121                      10M-20M    active
# 5            20231013                      10M-20M    active
# 6            20231105                      10M-20M    active
# 7            20230723                      10M-20M    active
# 8            20230627                      10M-20M    active
# 9            20231122                      10M-20M    active
#
#   ad.status_statement                                          ad.videos  \
# 0                 NaN  [{'url': 'https://v77.tiktokcdn.com/845faa77aa...
# 1                 NaN  [{'cover_image_url': 'https://p16-sign-va.tikt...
# 2                 NaN  [{'cover_image_url': 'https://p16-sign-sg.tikt...
# 3                 NaN  [{'cover_image_url': 'https://p16-sign-sg.tikt...
# 4                 NaN  [{'cover_image_url': 'https://p16-sign-sg.tikt...
# 5                 NaN  [{'url': 'https://v77.tiktokcdn.com/e966dc3ebb...
# 6                 NaN  [{'cover_image_url': 'https://p16-vod-sign-use...
# 7                 NaN  [{'cover_image_url': 'https://p16-vod-sign-use...
# 8                 NaN  [{'cover_image_url': 'https://p16-sign-sg.tikt...
# 9                 NaN  [{'cover_image_url': 'https://p16-sign-sg.tikt...
#
#    ad.first_shown_date  advertiser.business_id  \
# 0             20230906            6.979882e+18
# 1             20230101            6.876461e+18
# 2             20230421            7.209006e+18
# 3             20230914            6.979882e+18
# 4             20231023            6.888908e+18
# 5             20230918            6.888908e+18
# 6             20230913            6.883219e+18
# 7             20230605            6.876451e+18
# 8             20230111            6.899064e+18
# 9             20231017            6.979882e+18
#
#                             advertiser.business_name  ...  \
# 0  International Federation of Red Cross and Red ...  ...
# 1  BEIJING JIANG YU INTERACTIVE TECHNOLOGY CO., LTD.  ...
# 2                                           Ampsuite  ...
# 3  International Federation of Red Cross and Red ...  ...
# 4                                 TOP GAMES US, INC.  ...
# 5                                 TOP GAMES US, INC.  ...
# 6        Mondelez Deutschland Services GmbH & Co. KG  ...
# 7                                   Booking.com B.V.  ...
# 8                                  Metacore Games Oy  ...
# 9  International Federation of Red Cross and Red ...  ...
#
#   ad.reach.unique_users_seen_by_country.NO  \
# 0                                      NaN
# 1                                     561K
# 2                                      NaN
# 3                                      NaN
# 4                                     125K
# 5                                     126K
# 6                                      NaN
# 7                                      NaN
# 8                                     287K
# 9                                      NaN
#
#   ad.reach.unique_users_seen_by_country.DE  \
# 0                                      NaN
# 1                                     2.7M
# 2                                     3.6M
# 3                                      NaN
# 4                                      NaN
# 5                                      NaN
# 6                                    13.5M
# 7                                      NaN
# 8                                     1.4M
# 9                                      NaN
#
#   ad.reach.unique_users_seen_by_country.GR  \
# 0                                      NaN
# 1                                     383K
# 2                                      NaN
# 3                                      NaN
# 4                                     903K
# 5                                     818K
# 6                                      NaN
# 7                                      NaN
# 8                                      NaN
# 9                                      NaN
#
#   ad.reach.unique_users_seen_by_country.PT  \
# 0                                      NaN
# 1                                     427K
# 2                                      NaN
# 3                                      NaN
# 4                                     475K
# 5                                     510K
# 6                                      NaN
# 7                                      NaN
# 8                                      NaN
# 9                                      NaN
#
#    ad.reach.unique_users_seen_by_country.RO  \
# 0                                       NaN
# 1                                      851K
# 2                                       NaN
# 3                                       NaN
# 4                                      1.8M
# 5                                      1.9M
# 6                                       NaN
# 7                                       NaN
# 8                                       NaN
# 9                                       NaN
#
#    ad.reach.unique_users_seen_by_country.CH  \
# 0                                       NaN
# 1                                      522K
# 2                                       NaN
# 3                                       NaN
# 4                                      255K
# 5                                      220K
# 6                                       NaN
# 7                                       NaN
# 8                                      288K
# 9                                       NaN
#
#    ad.reach.unique_users_seen_by_country.GB  \
# 0                                       NaN
# 1                                      4.8M
# 2                                      3.1M
# 3                                       NaN
# 4                                       NaN
# 5                                       NaN
# 6                                       NaN
# 7                                       NaN
# 8                                      2.2M
# 9                                       NaN
#
#    ad.reach.unique_users_seen_by_country.FR  \
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                      1.9M
# 5                                      1.4M
# 6                                       NaN
# 7                                     15.7M
# 8                                      1.7M
# 9                                       NaN
#
#    ad.reach.unique_users_seen_by_country.HU  \
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                      668K
# 5                                      738K
# 6                                       NaN
# 7                                       NaN
# 8                                      491K
# 9                                       NaN
#
#    ad.reach.unique_users_seen_by_country.PL
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
# 5                                       NaN
# 6                                       NaN
# 7                                       NaN
# 8                                      1.4M
# 9                                       NaN
#
# [10 rows x 47 columns]

# %%
ads_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1995 entries, 0 to 1994
# Data columns (total 47 columns):
#  #   Column                                            Non-Null Count  Dtype
# ---  ------                                            --------------  -----
#  0   ad.id                                             1995 non-null   int64
#  1   ad.image_urls                                     1467 non-null   object
#  2   ad.last_shown_date                                1995 non-null   int64
#  3   ad.reach.unique_users_seen_x                      1995 non-null   object
#  4   ad.status                                         1995 non-null   object
#  5   ad.status_statement                               8 non-null      object
#  6   ad.videos                                         1995 non-null   object
#  7   ad.first_shown_date                               1995 non-null   int64
#  8   advertiser.business_id                            1987 non-null   float64
#  9   advertiser.business_name                          1987 non-null   object
#  10  advertiser.paid_for_by                            1987 non-null   object
#  11  ad_group.targeting_info.interest                  418 non-null    object
#  12  ad_group.targeting_info.number_of_users_targeted  1176 non-null   object
#  13  ad_group.targeting_info.video_interactions        152 non-null    object
#  14  ad_group.targeting_info.age.35-44                 1995 non-null   bool
#  15  ad_group.targeting_info.age.45-54                 1995 non-null   bool
#  16  ad_group.targeting_info.age.55+                   1995 non-null   bool
#  17  ad_group.targeting_info.age.13-17                 1995 non-null   bool
#  18  ad_group.targeting_info.age.18-24                 1995 non-null   bool
#  19  ad_group.targeting_info.age.25-34                 1995 non-null   bool
#  20  ad_group.targeting_info.audience_targeting        1995 non-null   object
#  21  ad_group.targeting_info.country                   1995 non-null   object
#  22  ad_group.targeting_info.creator_interactions      146 non-null    object
#  23  ad_group.targeting_info.gender.female             1995 non-null   bool
#  24  ad_group.targeting_info.gender.male               1995 non-null   bool
#  25  ad_group.targeting_info.gender.other_genders      1995 non-null   bool
#  26  ad.reach.unique_users_seen_y                      1995 non-null   object
#  27  ad.reach.unique_users_seen_by_country.DK          111 non-null    object
#  28  ad.reach.unique_users_seen_by_country.FI          143 non-null    object
#  29  ad.reach.unique_users_seen_by_country.IT          351 non-null    object
#  30  ad.reach.unique_users_seen_by_country.NL          143 non-null    object
#  31  ad.reach.unique_users_seen_by_country.CZ          103 non-null    object
#  32  ad.reach.unique_users_seen_by_country.BE          116 non-null    object
#  33  ad.reach.unique_users_seen_by_country.ES          281 non-null    object
#  34  ad.reach.unique_users_seen_by_country.IE          106 non-null    object
#  35  ad.reach.unique_users_seen_by_country.SE          111 non-null    object
#  36  ad.reach.unique_users_seen_by_country.AT          120 non-null    object
#  37  ad.reach.unique_users_seen_by_country.NO          103 non-null    object
#  38  ad.reach.unique_users_seen_by_country.DE          484 non-null    object
#  39  ad.reach.unique_users_seen_by_country.GR          94 non-null     object
#  40  ad.reach.unique_users_seen_by_country.PT          88 non-null     object
#  41  ad.reach.unique_users_seen_by_country.RO          101 non-null    object
#  42  ad.reach.unique_users_seen_by_country.CH          108 non-null    object
#  43  ad.reach.unique_users_seen_by_country.GB          710 non-null    object
#  44  ad.reach.unique_users_seen_by_country.FR          462 non-null    object
#  45  ad.reach.unique_users_seen_by_country.HU          60 non-null     object
#  46  ad.reach.unique_users_seen_by_country.PL          158 non-null    object
# dtypes: bool(9), float64(1), int64(3), object(34)
# memory usage: 609.9+ KB

# %%
# Assuming your DataFrame is named df
columns_to_keep = ['ad.id', 'ad.videos']

# Keep only the specified columns
ads_df = ads_df[columns_to_keep]

# %%
ads_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1995 entries, 0 to 1994
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   ad.id      1995 non-null   int64
#  1   ad.videos  1995 non-null   object
# dtypes: int64(1), object(1)
# memory usage: 31.3+ KB

# %%
# Export dataframe to csv
ads_df.to_csv('ads_id_ads_videos.csv', index=False)
